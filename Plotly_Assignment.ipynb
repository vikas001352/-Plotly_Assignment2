# %%
ANS-1


To plot a scatter plot for the "age" and "fare" columns of the Titanic dataset using Plotly Express, you'll need to load the dataset from another source. One option is to use the pandas library to load the dataset and then use plotly.express.scatter to create the scatter plot.

Here's how you can do it:


import pandas as pd
import plotly.express as px

# Load the Titanic dataset using pandas
# Make sure to have the 'titanic.csv' file in the same directory or provide the full path to the file.
titanic_df = pd.read_csv('titanic.csv')

# Create a scatter plot using Plotly Express
fig = px.scatter(titanic_df, x='age', y='fare', title='Scatter Plot of Age vs. Fare in Titanic Dataset')

# Show the plot
fig.show()


ANS-2

import plotly.express as px

# Load the tips dataset from Plotly Express
df_tips = px.data.tips

# Create a box plot using Plotly Express
fig = px.box(df_tips, y='total_bill', title='Box Plot of Total Bill in Tips Dataset')

# Show the plot
fig.show()


ANS-3


import plotly.express as px

# Load the tips dataset from Plotly Express
df_tips = px.data.tips

# Create a histogram using Plotly Express
fig = px.histogram(df_tips, x='sex', y='total_bill', 
                   color='day', pattern_shape='smoker', 
                   title='Histogram of Total Bill by Sex in Tips Dataset',
                   barmode='group')

# Show the plot
fig.show()

ANS-4


import plotly.express as px

# Assuming you have already loaded the iris dataset and named it 'iris_data'
# If you don't have it, you can load it with: from sklearn.datasets import load_iris; iris_data = load_iris()

# Convert the iris dataset to a pandas DataFrame (optional)
import pandas as pd
df = pd.DataFrame(data=iris_data.data, columns=iris_data.feature_names)
df['species'] = iris_data.target_names[iris_data.target]

# Create the scatter matrix plot
fig = px.scatter_matrix(df, dimensions=iris_data.feature_names, color='species', symbol='species')

# Update the layout (optional)
fig.update_layout(title='Scatter Matrix Plot - Iris Dataset', width=800, height=800)

# Show the plot
fig.show()


ANS-5
